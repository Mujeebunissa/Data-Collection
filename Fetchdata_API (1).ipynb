# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=1602de9771a7b7289abdfaa7e1243acc&language=en-US&page=1')

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','vote_average','vote_count']]

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','vote_average','vote_count']]
df

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...     113.290
# 1  Spanning the years 1945 to 1955, a chronicle o...      97.604
# 2  In the continuing saga of the Corleone crime f...      68.220
# 3  The true story of how businessman Oskar Schind...      54.465
# 4  The defense and the prosecution have rested an...      40.481
#
#    vote_average  vote_count
# 0         8.711       25539
# 1         8.707       19426
# 2         8.590       11714
# 3         8.571       15107
# 4         8.549        8019

# %%
df=pd.DataFrame(columns=['id','title','overview','popularity','vote_average','vote_count'])
df
# Out:
# Empty DataFrame
# Columns: [id, title, overview, popularity, vote_average, vote_count]
# Index: []

# %%
results_list=[]
for i in range(1,460):
  response=requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=1602de9771a7b7289abdfaa7e1243acc&language=en-US&page={i}')
  results_list.extend(response.json().get('results',[]))

df=pd.DataFrame(results_list)

# %%
df = df[['id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count']]

# %%
display(df)
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9161   5491           Battlefield Earth
# 9162  13805              Disaster Movie
# 9163  11059           House of the Dead
# 9164  14164        Dragonball Evolution
# 9165  40016  Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...     113.290
# 1     Spanning the years 1945 to 1955, a chronicle o...      97.604
# 2     In the continuing saga of the Corleone crime f...      68.220
# 3     The true story of how businessman Oskar Schind...      54.465
# 4     The defense and the prosecution have rested an...      40.481
# ...

# %%
df.shape
# Out:
# (9166, 6)

# %%
df.to_csv('movies.csv')
